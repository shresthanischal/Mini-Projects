# %% [markdown]
# # Artificial Neural Network

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers  import Dense
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('D:/DW/dataset_bank.csv')

# %%
data.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
x = data.iloc[:,:-1]
y = data['Exited']

# %%
for col in x.columns:
    if col=='Geography' or col =='Gender':
        x[col] = LabelEncoder().fit_transform(x.loc[:,[col]])
    else:
        x[col] = StandardScaler().fit_transform(x.loc[:,[col]])
# Out:
# C:\Users\Personal\anaconda3\envs\tf_dl\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
x.head()
# Out:
#    CreditScore  Geography  Gender       Age    Tenure   Balance  \
# 0    -0.326221          0       0  0.293517 -1.041760 -1.225848
# 1    -0.440036          2       0  0.198164 -1.387538  0.117350
# 2    -1.536794          0       0  0.293517  1.032908  1.333053
# 3     0.501521          0       0  0.007457 -1.387538 -1.225848
# 4     2.063884          2       0  0.388871 -1.041760  0.785728
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0      -0.911583   0.646092        0.970243         0.021886
# 1      -0.911583  -1.547768        0.970243         0.216534
# 2       2.527057   0.646092       -1.030670         0.240687
# 3       0.807737  -1.547768       -1.030670        -0.108918
# 4      -0.911583   0.646092        0.970243        -0.365276

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %% [markdown]
# Defining Sequential model

# %%
nn = Sequential()
nn.add(Dense(16, input_dim=10, activation='relu'))
nn.add(Dense(32,activation='relu'))
nn.add(Dense(16,activation='relu'))
nn.add(Dense(8,activation='relu'))
nn.add(Dense(4,activation='relu'))

nn.add(Dense(1,activation='sigmoid'))

nn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
nn.fit(x_train,y_train,epochs=50,batch_size=100)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 7500 samples
# Epoch 1/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3038 - accuracy: 0.8776
# Epoch 2/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.3034 - accuracy: 0.8775
# Epoch 3/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3050 - accuracy: 0.8761
# Epoch 4/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3037 - accuracy: 0.8771
# Epoch 5/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.3034 - accuracy: 0.8763
# Epoch 6/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3012 - accuracy: 0.8811
# Epoch 7/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.3012 - accuracy: 0.8795
# Epoch 8/50
# 7500/7500 [==============================] - 0s 38us/sample - loss: 0.3012 - accuracy: 0.8780
# Epoch 9/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.3017 - accuracy: 0.8784
# Epoch 10/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3006 - accuracy: 0.8796
# Epoch 11/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.3021 - accuracy: 0.8800
# Epoch 12/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.2992 - accuracy: 0.8785
# Epoch 13/50
# 7500/7500 [==============================] - 0s 44us/sample - loss: 0.2996 - accuracy: 0.8808
# Epoch 14/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.2993 - accuracy: 0.8793
# Epoch 15/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2988 - accuracy: 0.8789
# Epoch 16/50
# 7500/7500 [==============================] - 0s 47us/sample - loss: 0.2999 - accuracy: 0.8787
# Epoch 17/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.2997 - accuracy: 0.8803
# Epoch 18/50
# 7500/7500 [==============================] - 0s 47us/sample - loss: 0.2984 - accuracy: 0.8791
# Epoch 19/50
# 7500/7500 [==============================] - 0s 56us/sample - loss: 0.2963 - accuracy: 0.8819
# Epoch 20/50
# 7500/7500 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.87 - 0s 60us/sample - loss: 0.2977 - accuracy: 0.8795
# Epoch 21/50
# 7500/7500 [==============================] - 0s 51us/sample - loss: 0.2982 - accuracy: 0.8789
# Epoch 22/50
# 7500/7500 [==============================] - 0s 55us/sample - loss: 0.2975 - accuracy: 0.8804
# Epoch 23/50
# 7500/7500 [==============================] - 0s 49us/sample - loss: 0.2959 - accuracy: 0.8788
# Epoch 24/50
# 7500/7500 [==============================] - 0s 51us/sample - loss: 0.2958 - accuracy: 0.8809
# Epoch 25/50
# 7500/7500 [==============================] - 0s 52us/sample - loss: 0.2956 - accuracy: 0.8815
# Epoch 26/50
# 7500/7500 [==============================] - 0s 48us/sample - loss: 0.2951 - accuracy: 0.8835
# Epoch 27/50
# 7500/7500 [==============================] - 0s 55us/sample - loss: 0.2973 - accuracy: 0.8820
# Epoch 28/50
# 7500/7500 [==============================] - 0s 51us/sample - loss: 0.2948 - accuracy: 0.8823
# Epoch 29/50
# 7500/7500 [==============================] - 0s 52us/sample - loss: 0.2949 - accuracy: 0.8820
# Epoch 30/50
# 7500/7500 [==============================] - 0s 52us/sample - loss: 0.2935 - accuracy: 0.8811
# Epoch 31/50
# 7500/7500 [==============================] - 0s 40us/sample - loss: 0.2934 - accuracy: 0.8827
# Epoch 32/50
# 7500/7500 [==============================] - 0s 44us/sample - loss: 0.2939 - accuracy: 0.8827
# Epoch 33/50
# 7500/7500 [==============================] - 0s 49us/sample - loss: 0.2917 - accuracy: 0.8836
# Epoch 34/50
# 7500/7500 [==============================] - 0s 50us/sample - loss: 0.2927 - accuracy: 0.8820
# Epoch 35/50
# 7500/7500 [==============================] - 0s 54us/sample - loss: 0.2918 - accuracy: 0.8851
# Epoch 36/50
# 7500/7500 [==============================] - 0s 41us/sample - loss: 0.2922 - accuracy: 0.8829
# Epoch 37/50
# 7500/7500 [==============================] - 0s 43us/sample - loss: 0.2918 - accuracy: 0.8839
# Epoch 38/50
# 7500/7500 [==============================] - 0s 48us/sample - loss: 0.2934 - accuracy: 0.8840
# Epoch 39/50
# 7500/7500 [==============================] - 0s 47us/sample - loss: 0.2918 - accuracy: 0.8840
# Epoch 40/50
# 7500/7500 [==============================] - 0s 45us/sample - loss: 0.2935 - accuracy: 0.8831
# Epoch 41/50
# 7500/7500 [==============================] - 0s 49us/sample - loss: 0.2911 - accuracy: 0.8824
# Epoch 42/50
# 7500/7500 [==============================] - 0s 44us/sample - loss: 0.2911 - accuracy: 0.8837
# Epoch 43/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2901 - accuracy: 0.8843
# Epoch 44/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2894 - accuracy: 0.8852
# Epoch 45/50
# 7500/7500 [==============================] - 0s 46us/sample - loss: 0.2887 - accuracy: 0.8848
# Epoch 46/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2887 - accuracy: 0.8848
# Epoch 47/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2875 - accuracy: 0.8859
# Epoch 48/50
# 7500/7500 [==============================] - 0s 45us/sample - loss: 0.2899 - accuracy: 0.8840
# Epoch 49/50
# 7500/7500 [==============================] - 0s 42us/sample - loss: 0.2897 - accuracy: 0.8845
# Epoch 50/50
# 7500/7500 [==============================] - 0s 44us/sample - loss: 0.2864 - accuracy: 0.8881

# %%
_, accuracy = nn.evaluate(x_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 2500/2500 [==============================] - 0s 81us/sample - loss: 0.3746 - accuracy: 0.8516
# Accuracy: 85.16

# %% [markdown]
# Diabities

# %%
new = pd.read_csv('D:/DW/diabetes.csv')

# %%
new.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = new.iloc[:,:-1]
y = new['Outcome']

# %%
for col in x.columns:
    x[col] = StandardScaler().fit_transform(x.loc[:,[col]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
model = Sequential()
model.add(Dense(16, input_dim=8, activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1      -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2       1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3      -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4      -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
# ..           ...       ...            ...            ...       ...       ...
# 763     1.827813 -0.622642       0.356432       1.722735  0.870031  0.115169
# 764    -0.547919  0.034598       0.046245       0.405445 -0.692891  0.610154
# 765     0.342981  0.003301       0.149641       0.154533  0.279594 -0.735190
# 766    -0.844885  0.159787      -0.470732      -1.288212 -0.692891 -0.240205
# 767    -0.844885 -0.873019       0.046245       0.656358 -0.692891 -0.202129
#
#      DiabetesPedigreeFunction       Age
# 0                    0.468492  1.425995
# 1                   -0.365061 -0.190672
# 2                    0.604397 -0.105584
# 3                   -0.920763 -1.041549
# 4                    5.484909 -0.020496
# ..                        ...       ...
# 763                 -0.908682  2.532136
# 764                 -0.398282 -0.531023
# 765                 -0.685193 -0.275760
# 766                 -0.371101  1.170732
# 767                 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %%
model.fit(x_train,y_train,epochs=50,batch_size=32)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on